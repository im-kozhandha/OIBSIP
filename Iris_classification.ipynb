# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_iris=pd.read_csv(r"E:\Internship material\Oasis\Iris.csv")
#data_iris.head()
data_iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(data_iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#renaming columns
data_iris.columns= ['ID','Sepal_length','Sepal_width','Petal_length','Petal_width','Species']
data_iris.head()
# Out:
#    ID  Sepal_length  Sepal_width  Petal_length  Petal_width      Species
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data_iris.tail()
# Out:
#       ID  Sepal_length  Sepal_width  Petal_length  Petal_width         Species
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica

# %%
print(data_iris.shape)
# Out:
# (150, 6)

# %%
print(data_iris.describe)
# Out:
# <bound method NDFrame.describe of       ID  Sepal_length  Sepal_width  Petal_length  Petal_width         Species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# ...

# %%
print(data_iris.isna())
print(data_iris.isna().sum())
# Out:
#         ID  Sepal_length  Sepal_width  Petal_length  Petal_width  Species
# 0    False         False        False         False        False    False
# 1    False         False        False         False        False    False
# 2    False         False        False         False        False    False
# 3    False         False        False         False        False    False
# 4    False         False        False         False        False    False
# ..     ...           ...          ...           ...          ...      ...
# 145  False         False        False         False        False    False
# 146  False         False        False         False        False    False
# 147  False         False        False         False        False    False
# 148  False         False        False         False        False    False
# 149  False         False        False         False        False    False
#
# [150 rows x 6 columns]
# ID              0
# Sepal_length    0
# Sepal_width     0
# ...

# %%
#no.of species respectively
n1 = len(data_iris[data_iris['Species'] == 'Iris-versicolor'])
print("No of Species Versicolor in Dataset:",n1)
n2 = len(data_iris[data_iris['Species'] == 'Iris-virginica'])
print("No of Species Virginica in Dataset:",n2)
n3 = len(data_iris[data_iris['Species'] == 'Iris-setosa'])
print("No of Species Versicolor in Dataset:",n3)
# Out:
# No of Species Versicolor in Dataset: 50
# No of Species Virginica in Dataset: 50
# No of Species Versicolor in Dataset: 50

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
l = ['Versicolor', 'Setosa', 'Virginica']
s = [50,50,50]  #from prev. code cell
ax.pie(s, labels = l,autopct='%1.2f%%')
plt.show()

# %%
plt.figure(1)
plt.boxplot([data_iris['Sepal_length']])
plt.figure(2)
plt.boxplot([data_iris['Sepal_width']])
plt.figure(3)
plt.boxplot([data_iris['Petal_length']])
plt.figure(4)
plt.boxplot([data_iris['Petal_width']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ba81c4f150>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ba81c5c550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ba81c4e890>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ba81c5d490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ba81c4dfd0>],
#  'means': []}

# %%
#histogram
data_iris.hist()
plt.show()

# %%
data_iris.plot(kind ='density',subplots = True, layout =(3,3),sharex = False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>]], dtype=object)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='Petal_length',data=data_iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='Petal_width',data=data_iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='Sepal_length',data=data_iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='Sepal_width',data=data_iris)
# Out:
# <Axes: xlabel='Species', ylabel='Sepal_width'>

# %%
plt.figure()
sns.pairplot(data_iris,hue='Species');
